# %% [markdown]
# # Crime in Montevideo, Uruguay
# ### Uruguay is considered a safe country in Latin America, especially compared to its neighbors. However, crime in Uruguay, and in its capital Montevideo in particular, has increased significantly in the last decade.
# ### The aim of this analysis is to have a better understanding of which parts of Montevideo have a higher rate of crime and what's the relationship with other variables (police presence and economic level).
# ### In order to do this the following data will be used:
# ### - Foursquare information of venues in Montevideo. Foursqueare is mainly used by tourists or by Uruguayans that belong to high-income classes. As per this, the venues provided by Foursquare will be used as a proxy for areas that have a higher presence of police and are high-income.
# ### - Location of Police Stations in Montevideo. This information was obtained from a Government site (Ministerio de Desarollo Social).
# ### - Number of Crimes during 2019 reported per Police Station. This information was also obtained from a Government site (Ministerio del Interior).

# %% [markdown]
# #### Import libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes 
# uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Libraries imported.

# %% [markdown]
# #### Set credentials for Foursquare and obtain venue information from Montevideo, Uruguay

# %%
CLIENT_ID = 'JGSHF3NQXMWZ44ER1KJKECJOWWRWZNOLEOANVP3J2EWFH4GK' # your Foursquare ID
CLIENT_SECRET = 'RTALTWRS2KQFDPERC3SPRJNNFWJZSHDIOUPHIBLQB5T52K1V' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: JGSHF3NQXMWZ44ER1KJKECJOWWRWZNOLEOANVP3J2EWFH4GK
# CLIENT_SECRET:RTALTWRS2KQFDPERC3SPRJNNFWJZSHDIOUPHIBLQB5T52K1V

# %%
address = 'Montevideo, UY'

geolocator = Nominatim(user_agent="mvd_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Montevideo are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of Montevideo are -34.9059039, -56.1913569.

# %%
radius = 10000 #define radius
LIMIT = 1000 #limit of number of venues returned by Fursquare API

url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=JGSHF3NQXMWZ44ER1KJKECJOWWRWZNOLEOANVP3J2EWFH4GK&client_secret=RTALTWRS2KQFDPERC3SPRJNNFWJZSHDIOUPHIBLQB5T52K1V&ll=-34.9059039,-56.1913569&v=20180605&radius=10000&limit=1000'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5f382ff5dd2e0829bbf23112'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Montevideo',
#   'headerFullLocation': 'Montevideo',
#   'headerLocationGranularity': 'city',
#   'totalResults': 203,
#   'suggestedBounds': {'ne': {'lat': -34.81590380999991,
#     'lng': -56.081818032194775},
#    'sw': {'lat': -34.99590399000009, 'lng': -56.30089576780523}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c7eeaf48e6495210aa112bd',
#        'name': 'Auditorio Nacional del Sodre Dra. Adela Reta',
#        'location': {'address': 'Andes',
#         'crossStreet': 'Mercedes',
#         'lat': -34.9044896879589,
#         'lng': -56.19839471139537,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.9044896879589,
#           'lng': -56.19839471139537}],
#         'distance': 661,
#         'postalCode': '11100',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Andes (Mercedes)',
#          '11100 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '5032792091d4c4b30a586d5c',
#          'name': 'Concert Hall',
#          'pluralName': 'Concert Halls',
#          'shortName': 'Concert Hall',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/musicvenue_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c7eeaf48e6495210aa112bd-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c0d204363c3ef3b0cf3a693',
#        'name': 'Ashot Shawarma',
#        'location': {'address': 'Zelmar Michelini 1295',
#         'lat': -34.90731405807303,
#         'lng': -56.190218925476074,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90731405807303,
#           'lng': -56.190218925476074}],
#         'distance': 188,
#         'postalCode': '11100',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Zelmar Michelini 1295',
#          '11100 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '5283c7b4e4b094cb91ec88d7',
#          'name': 'Kebab Restaurant',
#          'pluralName': 'Kebab Restaurants',
#          'shortName': 'Kebab',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/middleeastern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c0d204363c3ef3b0cf3a693-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54a09d5b498e03eea60235b5',
#        'name': 'Smart Hotel Montevideo',
#        'location': {'address': 'Andes 1240',
#         'crossStreet': 'Soriano',
#         'lat': -34.90840580965659,
#         'lng': -56.19781916370278,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90840580965659,
#           'lng': -56.19781916370278}],
#         'distance': 652,
#         'postalCode': '11100',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Andes 1240 (Soriano)',
#          '11100 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1fa931735',
#          'name': 'Hotel',
#          'pluralName': 'Hotels',
#          'shortName': 'Hotel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/travel/hotel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54a09d5b498e03eea60235b5-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ee9e13661aff2afce03855c',
#        'name': 'La Ibérica',
#        'location': {'address': 'Rincon 711',
#         'crossStreet': 'Juncal',
#         'lat': -34.90531927669457,
#         'lng': -56.20106908434599,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90531927669457,
#           'lng': -56.20106908434599}],
#         'distance': 889,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'neighborhood': 'Ciudad Vieja, Montevideo, Montevideo',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Rincon 711 (Juncal)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ee9e13661aff2afce03855c-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '55cfecd6498e5e99b672f823',
#        'name': 'Candy Bar Palermo',
#        'location': {'address': 'Durazno 1402',
#         'crossStreet': 'Santiago De Chile',
#         'lat': -34.910186888885114,
#         'lng': -56.18501984512913,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.910186888885114,
#           'lng': -56.18501984512913}],
#         'distance': 749,
#         'postalCode': '11200',
#         'cc': 'UY',
#         'city': 'Palermo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Durazno 1402 (Santiago De Chile)',
#          '11200 Palermo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-55cfecd6498e5e99b672f823-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e6b97d2c65b5bef28e62057',
#        'name': 'La Pasionaria',
#        'location': {'address': 'Reconquista 587',
#         'crossStreet': 'esq Juan Carlos Gómez',
#         'lat': -34.90868578638685,
#         'lng': -56.202241520404904,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90868578638685,
#           'lng': -56.202241520404904}],
#         'distance': 1040,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Reconquista 587 (esq Juan Carlos Gómez)',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1f4941735',
#          'name': 'Design Studio',
#          'pluralName': 'Design Studios',
#          'shortName': 'Design',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/design_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33364757'}},
#       'referralId': 'e-0-4e6b97d2c65b5bef28e62057-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b865269f964a520f48531e3',
#        'name': 'Teatro Solís',
#        'location': {'address': 'Buenos Aires s/nº',
#         'crossStreet': 'e/ Liniers y Bartolomé Mitre',
#         'lat': -34.907373819893394,
#         'lng': -56.201207155866335,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.907373819893394,
#           'lng': -56.201207155866335}],
#         'distance': 914,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Buenos Aires s/nº (e/ Liniers y Bartolomé Mitre)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d136941735',
#          'name': 'Opera House',
#          'pluralName': 'Opera Houses',
#          'shortName': 'Opera House',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/performingarts_operahouse_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b865269f964a520f48531e3-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f67800977162794966e837a',
#        'name': 'Rambla Gran Bretaña',
#        'location': {'address': 'Rambla Gran Bretaña',
#         'crossStreet': 'e/ Misiones y Convención',
#         'lat': -34.91063982044504,
#         'lng': -56.200711727142334,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.91063982044504,
#           'lng': -56.200711727142334}],
#         'distance': 1003,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Rambla Gran Bretaña (e/ Misiones y Convención)',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f67800977162794966e837a-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e610556d22d509a38fea4d0',
#        'name': 'La Cocina de Pedro',
#        'location': {'address': 'Gonzalo Ramírez 1483',
#         'crossStreet': 'e/ Barrios Amorín y Martínez Trueba',
#         'lat': -34.91255904690403,
#         'lng': -56.18315321558815,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.91255904690403,
#           'lng': -56.18315321558815}],
#         'distance': 1053,
#         'postalCode': '11100',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Gonzalo Ramírez 1483 (e/ Barrios Amorín y Martínez Trueba)',
#          '11100 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1cd941735',
#          'name': 'South American Restaurant',
#          'pluralName': 'South American Restaurants',
#          'shortName': 'South American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e610556d22d509a38fea4d0-8'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ba43a76f964a520988e38e3',
#        'name': 'Plaza Independencia',
#        'location': {'address': 'Av. 18 de Julio',
#         'crossStreet': 'esq. Plaza Independencia',
#         'lat': -34.906369719166506,
#         'lng': -56.19948931433754,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.906369719166506,
#           'lng': -56.19948931433754}],
#         'distance': 744,
#         'postalCode': '11100',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Av. 18 de Julio (esq. Plaza Independencia)',
#          '11100 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ba43a76f964a520988e38e3-9'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfb916c18a8fc7fb4407e45',
#        'name': 'Estrecho',
#        'location': {'address': 'Sarandí 460',
#         'crossStreet': 'e/ Misiones y Treinta y Tres',
#         'lat': -34.90782423276405,
#         'lng': -56.205743473235074,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90782423276405,
#           'lng': -56.205743473235074}],
#         'distance': 1330,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Sarandí 460 (e/ Misiones y Treinta y Tres)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1cd941735',
#          'name': 'South American Restaurant',
#          'pluralName': 'South American Restaurants',
#          'shortName': 'South American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/argentinian_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4dfb916c18a8fc7fb4407e45-10'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59b42fbbbe70782b654ae75e',
#        'name': 'Renner',
#        'location': {'lat': -34.90537038532569,
#         'lng': -56.187976050634994,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90537038532569,
#           'lng': -56.187976050634994}],
#         'distance': 314,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Montevideo Montevideo', 'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d103951735',
#          'name': 'Clothing Store',
#          'pluralName': 'Clothing Stores',
#          'shortName': 'Apparel',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59b42fbbbe70782b654ae75e-11'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd9d0452e6f0f47a71a0c08',
#        'name': 'Centro Cultural de España',
#        'location': {'address': 'Rincon 629',
#         'crossStreet': 'Bartolomé Mitre',
#         'lat': -34.90586214206671,
#         'lng': -56.202737928774496,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90586214206671,
#           'lng': -56.202737928774496}],
#         'distance': 1039,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Rincon 629 (Bartolomé Mitre)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1e2931735',
#          'name': 'Art Gallery',
#          'pluralName': 'Art Galleries',
#          'shortName': 'Art Gallery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/artgallery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd9d0452e6f0f47a71a0c08-12'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5a4d078660255e14fd30b56a',
#        'name': 'La Greca Café',
#        'location': {'address': 'San Salvador 1471',
#         'crossStreet': 'Martínez Trueba',
#         'lat': -34.91176597399569,
#         'lng': -56.183427572250366,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.91176597399569,
#           'lng': -56.183427572250366}],
#         'distance': 974,
#         'postalCode': '11200',
#         'cc': 'UY',
#         'neighborhood': 'Palermo',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['San Salvador 1471 (Martínez Trueba)',
#          '11200 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '465625968'}},
#       'referralId': 'e-0-5a4d078660255e14fd30b56a-13'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b5e0c9cf964a520f27a29e3',
#        'name': 'Plaza Matriz',
#        'location': {'address': 'Sarandí',
#         'crossStreet': 'Juan Carlos Gómez',
#         'lat': -34.906615,
#         'lng': -56.203541,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.906615,
#           'lng': -56.203541}],
#         'distance': 1115,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Sarandí (Juan Carlos Gómez)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b5e0c9cf964a520f27a29e3-14'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e282ba652b1c37d35bed993',
#        'name': 'Confitería 25 De Mayo',
#        'location': {'address': '25 de Mayo 655',
#         'crossStreet': 'Bartolome Mitre',
#         'lat': -34.904802,
#         'lng': -56.202645,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.904802,
#           'lng': -56.202645}],
#         'distance': 1037,
#         'postalCode': '11200',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['25 de Mayo 655 (Bartolome Mitre)',
#          '11200 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'shortName': 'Desserts',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '54286446'}},
#       'referralId': 'e-0-4e282ba652b1c37d35bed993-15'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4e3ea4c8b0fb875af871abd2',
#        'name': 'Rambla República Argentina',
#        'location': {'address': 'Rambla República Argentina',
#         'crossStreet': 'e/ Río Negro y Jackson',
#         'lat': -34.915162,
#         'lng': -56.182323,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.915162,
#           'lng': -56.182323}],
#         'distance': 1319,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Rambla República Argentina (e/ Río Negro y Jackson)',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d165941735',
#          'name': 'Scenic Lookout',
#          'pluralName': 'Scenic Lookouts',
#          'shortName': 'Scenic Lookout',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sceniclookout_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4e3ea4c8b0fb875af871abd2-16'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5540fc4e498e22f511f8f17a',
#        'name': 'Sin Pretensiones',
#        'location': {'address': 'Sarandi 366',
#         'crossStreet': 'Alzaibar',
#         'lat': -34.90842404795427,
#         'lng': -56.207494918292916,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90842404795427,
#           'lng': -56.207494918292916}],
#         'distance': 1499,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Sarandi 366 (Alzaibar)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '52e81612bcbc57f1066b7a00',
#          'name': 'Comfort Food Restaurant',
#          'pluralName': 'Comfort Food Restaurants',
#          'shortName': 'Comfort Food',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5540fc4e498e22f511f8f17a-17'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '574a392c498edddeb7397933',
#        'name': 'Escarmuza Librería y Café',
#        'location': {'address': 'Pablo de María 1185',
#         'crossStreet': 'Canelones',
#         'lat': -34.90650320148671,
#         'lng': -56.171223838037584,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90650320148671,
#           'lng': -56.171223838037584}],
#         'distance': 1839,
#         'cc': 'UY',
#         'neighborhood': 'Cordón',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Pablo de María 1185 (Canelones)',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'shortName': 'Bookstore',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-574a392c498edddeb7397933-18'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '54ba8a72498e6f934a0c675a',
#        'name': 'Primuseum',
#        'location': {'address': 'Perez Castellano 1389',
#         'crossStreet': 'Washington',
#         'lat': -34.908497176040605,
#         'lng': -56.2102345533608,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.908497176040605,
#           'lng': -56.2102345533608}],
#         'distance': 1747,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Perez Castellano 1389 (Washington)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-54ba8a72498e6f934a0c675a-19'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d5124bedcce224bc9bdde1b',
#        'name': 'Plaza Fabini',
#        'location': {'address': 'Av. 18 de Julio',
#         'crossStreet': 'e/ Río Negro y Julio Herrera y Obes',
#         'lat': -34.905646727034565,
#         'lng': -56.19428515434265,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.905646727034565,
#           'lng': -56.19428515434265}],
#         'distance': 268,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Av. 18 de Julio (e/ Río Negro y Julio Herrera y Obes)',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d5124bedcce224bc9bdde1b-20'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59fd071781635b4c2193431a',
#        'name': 'Mercado Ferrando',
#        'location': {'address': 'Chana 2120',
#         'crossStreet': 'Joaquín de Salterain',
#         'lat': -34.904439133600086,
#         'lng': -56.17065290397829,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.904439133600086,
#           'lng': -56.17065290397829}],
#         'distance': 1897,
#         'postalCode': '11200',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Chana 2120 (Joaquín de Salterain)',
#          '11200 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'shortName': 'Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59fd071781635b4c2193431a-21'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c8047e751ada1cdd39c0810',
#        'name': 'El Mingus',
#        'location': {'address': 'San Salvador 1952',
#         'crossStreet': 'Jackson',
#         'lat': -34.91115588502369,
#         'lng': -56.17264677579298,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.91115588502369,
#           'lng': -56.17264677579298}],
#         'distance': 1805,
#         'postalCode': '11200',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['San Salvador 1952 (Jackson)',
#          '11200 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c8047e751ada1cdd39c0810-22'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57815c39498e4ecb4f660460',
#        'name': 'Montevideo Wine Experience',
#        'location': {'lat': -34.905212,
#         'lng': -56.211791,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.905212,
#           'lng': -56.211791}],
#         'distance': 1867,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Montevideo Montevideo', 'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d123941735',
#          'name': 'Wine Bar',
#          'pluralName': 'Wine Bars',
#          'shortName': 'Wine Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57815c39498e4ecb4f660460-23'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '548b8d16498e13d74f2e87b5',
#        'name': 'Hey chopp',
#        'location': {'address': 'Paullier',
#         'crossStreet': 'Rivera',
#         'lat': -34.9014302082931,
#         'lng': -56.16800288183097,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.9014302082931,
#           'lng': -56.16800288183097}],
#         'distance': 2189,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Paullier (Rivera)',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-548b8d16498e13d74f2e87b5-24'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4df7a6ad152069aa37eb05f6',
#        'name': 'Puerta de la Ciudadela',
#        'location': {'address': 'Juncal',
#         'crossStreet': 'Sarandí',
#         'lat': -34.906578606670564,
#         'lng': -56.20095023290063,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.906578606670564,
#           'lng': -56.20095023290063}],
#         'distance': 879,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Juncal (Sarandí)',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d12d941735',
#          'name': 'Monument / Landmark',
#          'pluralName': 'Monuments / Landmarks',
#          'shortName': 'Landmark',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4df7a6ad152069aa37eb05f6-25'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '59fde9653af9880feb5e623f',
#        'name': 'The Lab Coffee Roasters',
#        'location': {'address': 'Sarandí 285',
#         'lat': -34.9088912630134,
#         'lng': -56.209134445557495,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.9088912630134,
#           'lng': -56.209134445557495}],
#         'distance': 1656,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'neighborhood': 'Ciudad Vieja',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Sarandí 285',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59fde9653af9880feb5e623f-26'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5ab078f7d552c772d00f0e95',
#        'name': 'Che.co.ffe',
#        'location': {'address': 'Zabala 1341',
#         'crossStreet': 'Sarandi',
#         'lat': -34.908427,
#         'lng': -56.206793,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.908427,
#           'lng': -56.206793}],
#         'distance': 1436,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'neighborhood': 'Ciudad Vieja',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Zabala 1341 (Sarandi)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5ab078f7d552c772d00f0e95-27'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b9339d3f964a520193c34e3',
#        'name': 'Parque José Enrique Rodó',
#        'location': {'address': 'Av. Julio Herrera y Reissig',
#         'crossStreet': 'esq. Gonzalo Ramírez y Sarmiento',
#         'lat': -34.91479243511695,
#         'lng': -56.16772055625915,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.91479243511695,
#           'lng': -56.16772055625915}],
#         'distance': 2373,
#         'postalCode': '11300',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Av. Julio Herrera y Reissig (esq. Gonzalo Ramírez y Sarmiento)',
#          '11300 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b9339d3f964a520193c34e3-28'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4be55f048a8cb7136b5fc4a0',
#        'name': 'Plaza Zabala',
#        'location': {'address': 'Circunvalación Durango',
#         'lat': -34.90756095820422,
#         'lng': -56.20811688449313,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90756095820422,
#           'lng': -56.20811688449313}],
#         'distance': 1541,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Circunvalación Durango',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4be55f048a8cb7136b5fc4a0-29'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50edf554e4b08462bc26b131',
#        'name': 'Fénix',
#        'location': {'address': 'Juan Carlos Gomez 1251',
#         'crossStreet': 'Reconquista',
#         'lat': -34.908601422440015,
#         'lng': -56.20205391643147,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.908601422440015,
#           'lng': -56.20205391643147}],
#         'distance': 1021,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Juan Carlos Gomez 1251 (Reconquista)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-50edf554e4b08462bc26b131-30'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b60acacf964a52075f329e3',
#        'name': 'Plaza de Cagancha',
#        'location': {'address': 'Av. 18 de Julio',
#         'crossStreet': 'e/ Pasaje de los Derechos Humanos y Plaza Cagancha',
#         'lat': -34.90593632457969,
#         'lng': -56.19130374626683,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90593632457969,
#           'lng': -56.19130374626683}],
#         'distance': 6,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Av. 18 de Julio (e/ Pasaje de los Derechos Humanos y Plaza Cagancha)',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d164941735',
#          'name': 'Plaza',
#          'pluralName': 'Plazas',
#          'shortName': 'Plaza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/plaza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b60acacf964a52075f329e3-31'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58b2321aac329112134e282f',
#        'name': 'Frog 15',
#        'location': {'lat': -34.90660608493252,
#         'lng': -56.17783777758254,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90660608493252,
#           'lng': -56.17783777758254}],
#         'distance': 1236,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Montevideo Montevideo', 'Uruguay']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b46',
#          'name': 'Supermarket',
#          'pluralName': 'Supermarkets',
#          'shortName': 'Supermarket',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58b2321aac329112134e282f-32'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c1f6ab6a34cd13add027d74',
#        'name': 'Mercado del Puerto',
#        'location': {'address': 'Piedras 237',
#         'crossStreet': 'Pérez Castellano',
#         'lat': -34.90569659253122,
#         'lng': -56.211695036874374,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90569659253122,
#           'lng': -56.211695036874374}],
#         'distance': 1856,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Piedras 237 (Pérez Castellano)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d120951735',
#          'name': 'Food Court',
#          'pluralName': 'Food Courts',
#          'shortName': 'Food Court',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_foodcourt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33723929'}},
#       'referralId': 'e-0-4c1f6ab6a34cd13add027d74-33'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4c864bc051ada1cdb2b93e10',
#        'name': 'Café Brasilero',
#        'location': {'address': 'Ituzaingó 1447',
#         'crossStreet': 'e/ 25 de Mayo y Rincón',
#         'lat': -34.905741,
#         'lng': -56.204651,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.905741,
#           'lng': -56.204651}],
#         'distance': 1213,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'neighborhood': 'Ciudad Vieja',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Ituzaingó 1447 (e/ 25 de Mayo y Rincón)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'shortName': 'Café',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4c864bc051ada1cdb2b93e10-34'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4b559580f964a52024e827e3',
#        'name': 'Museo Nacional de Artes Visuales del Parque Rodó',
#        'location': {'address': 'Julio Herrera y Reissig s/n',
#         'crossStreet': 'Tomás Giribaldi',
#         'lat': -34.91389205947445,
#         'lng': -56.16477119903903,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.91389205947445,
#           'lng': -56.16477119903903}],
#         'distance': 2584,
#         'postalCode': '11300',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Julio Herrera y Reissig s/n (Tomás Giribaldi)',
#          '11300 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4b559580f964a52024e827e3-35'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '51b86f812fc6b6ab1f650c6c',
#        'name': 'Mercado Agrícola de Montevideo',
#        'location': {'address': 'José L. Terra 2220',
#         'crossStreet': 'e/ Martín García y Amézaga',
#         'lat': -34.88703025547493,
#         'lng': -56.1834520926693,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.88703025547493,
#           'lng': -56.1834520926693}],
#         'distance': 2221,
#         'postalCode': '11800',
#         'cc': 'UY',
#         'neighborhood': 'Aguada',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['José L. Terra 2220 (e/ Martín García y Amézaga)',
#          '11800 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '50be8ee891d4fa8dcc7199a7',
#          'name': 'Market',
#          'pluralName': 'Markets',
#          'shortName': 'Market',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/market_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-51b86f812fc6b6ab1f650c6c-36'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5008373264a449a4410eabc0',
#        'name': 'Arquetipo',
#        'location': {'address': 'Constituyente 1875',
#         'crossStreet': 'frugoni',
#         'lat': -34.90688293086517,
#         'lng': -56.17562770843506,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90688293086517,
#           'lng': -56.17562770843506}],
#         'distance': 1440,
#         'postalCode': '11100',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Constituyente 1875 (frugoni)',
#          '11100 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'shortName': 'Furniture / Home',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '33189554'}},
#       'referralId': 'e-0-5008373264a449a4410eabc0-37'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5409db59498ed28daa8be69a',
#        'name': 'El Bajo - Ciudad Vieja',
#        'location': {'address': 'Juan Carlos Gomez',
#         'crossStreet': 'Piedras',
#         'lat': -34.903706827118214,
#         'lng': -56.20419047969604,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.903706827118214,
#           'lng': -56.20419047969604}],
#         'distance': 1196,
#         'postalCode': '11100',
#         'cc': 'UY',
#         'city': 'Ciudad Vieja',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Juan Carlos Gomez (Piedras)',
# ...
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-59865b14e97dfb6a1546fe58-86'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5820afcab613dc5c3166f397',
#        'name': 'Montevideo Beer Company',
#        'location': {'address': 'Bulevar España 2600',
#         'crossStreet': 'Dr. Enrique Muñoz',
#         'lat': -34.91294052554716,
#         'lng': -56.1575065915516,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.91294052554716,
#           'lng': -56.1575065915516}],
#         'distance': 3187,
#         'postalCode': '11200',
#         'cc': 'UY',
#         'city': 'Pocitos',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Bulevar España 2600 (Dr. Enrique Muñoz)',
#          '11200 Pocitos Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'shortName': 'Brewery',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5820afcab613dc5c3166f397-87'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bff58b6369476b0eac08d1f',
#        'name': 'Ponte Vecchio',
#        'location': {'address': 'Rivera 2619',
#         'crossStreet': 'Simón Bolivar',
#         'lat': -34.903038268800636,
#         'lng': -56.15851006989797,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.903038268800636,
#           'lng': -56.15851006989797}],
#         'distance': 3015,
#         'postalCode': '11600',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Rivera 2619 (Simón Bolivar)',
#          '11600 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bff58b6369476b0eac08d1f-88'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '50a83f8ae4b0f191c1746acd',
#        'name': 'Gallaghers Irish Pub',
#        'location': {'address': 'Pagola 3233',
#         'crossStreet': '26 de Marzo',
#         'lat': -34.90831274580224,
#         'lng': -56.146008777887985,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90831274580224,
#           'lng': -56.146008777887985}],
#         'distance': 4148,
#         'postalCode': '11300',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Pagola 3233 (26 de Marzo)',
#          '11300 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d116941735',
#          'name': 'Bar',
#          'pluralName': 'Bars',
#          'shortName': 'Bar',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '130127961'}},
#       'referralId': 'e-0-50a83f8ae4b0f191c1746acd-89'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5bc20ef7f709c100391e94af',
#        'name': 'The Lab Coffee Roasters',
#        'location': {'address': 'Jose Luis Zorillo de San Martin 146',
#         'lat': -34.92725,
#         'lng': -56.159788,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.92725,
#           'lng': -56.159788}],
#         'distance': 3734,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Jose Luis Zorillo de San Martin 146',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5bc20ef7f709c100391e94af-90'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bae44c3f964a520fc9a3be3',
#        'name': 'La Chacra del Puerto',
#        'location': {'address': 'Mercado del Puerto',
#         'crossStreet': 'Piedras 237',
#         'lat': -34.905734005124124,
#         'lng': -56.21166394314542,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.905734005124124,
#           'lng': -56.21166394314542}],
#         'distance': 1853,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Mercado del Puerto (Piedras 237)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1df931735',
#          'name': 'BBQ Joint',
#          'pluralName': 'BBQ Joints',
#          'shortName': 'BBQ',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bae44c3f964a520fc9a3be3-91'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '57db60f4498e710fa6b66bd2',
#        'name': 'RUDY Burgers',
#        'location': {'address': '26 de marzo 3471',
#         'crossStreet': 'Luis Alberto de Herrera',
#         'lat': -34.906017,
#         'lng': -56.138683,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.906017,
#           'lng': -56.138683}],
#         'distance': 4808,
#         'cc': 'UY',
#         'neighborhood': 'Pocitos',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['26 de marzo 3471 (Luis Alberto de Herrera)',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d16c941735',
#          'name': 'Burger Joint',
#          'pluralName': 'Burger Joints',
#          'shortName': 'Burgers',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/burger_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-57db60f4498e710fa6b66bd2-92'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '5659caaa498efbd1a78d4207',
#        'name': 'Letrero Montevideo',
#        'location': {'lat': -34.91044544043599,
#         'lng': -56.138525530347216,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.91044544043599,
#           'lng': -56.138525530347216}],
#         'distance': 4849,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Montevideo Montevideo', 'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d12d941735',
#          'name': 'Monument / Landmark',
#          'pluralName': 'Monuments / Landmarks',
#          'shortName': 'Landmark',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/government_monument_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-5659caaa498efbd1a78d4207-93'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '501feb64e4b067f6adf254cd',
#        'name': 'Úrbani Plaza Zabala',
#        'location': {'address': 'Circunvalación Durango 381',
#         'crossStreet': 'Primero de Mayo',
#         'lat': -34.90748569268829,
#         'lng': -56.20792433524489,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90748569268829,
#           'lng': -56.20792433524489}],
#         'distance': 1522,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Circunvalación Durango 381 (Primero de Mayo)',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1be941735',
#          'name': 'Latin American Restaurant',
#          'pluralName': 'Latin American Restaurants',
#          'shortName': 'Latin American',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/latinamerican_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-501feb64e4b067f6adf254cd-94'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4ed7887fcc21a6423f6c0f3e',
#        'name': 'Es Mercat',
#        'location': {'address': 'Colón 1550',
#         'crossStreet': 'e/ Piedras y Cerrito',
#         'lat': -34.90564787827718,
#         'lng': -56.21027882759006,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90564787827718,
#           'lng': -56.21027882759006}],
#         'distance': 1727,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Colón 1550 (e/ Piedras y Cerrito)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d14f941735',
#          'name': 'Southern / Soul Food Restaurant',
#          'pluralName': 'Southern / Soul Food Restaurants',
#          'shortName': 'Southern / Soul',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/southern_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4ed7887fcc21a6423f6c0f3e-95'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4cfe2091c6cca35da85c9a32',
#        'name': 'Parque Del Prado',
#        'location': {'lat': -34.86017473491801,
#         'lng': -56.20032372655452,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.86017473491801,
#           'lng': -56.20032372655452}],
#         'distance': 5155,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Montevideo Montevideo', 'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d163941735',
#          'name': 'Park',
#          'pluralName': 'Parks',
#          'shortName': 'Park',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/park_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4cfe2091c6cca35da85c9a32-96'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4f43ba5fe4b03c8ff6d2112b',
#        'name': 'Volverás a Mi Boutique de Chocolate',
#        'location': {'address': 'Pérez Castellano 1461',
#         'crossStreet': '25 de mayo',
#         'lat': -34.90723925345805,
#         'lng': -56.210714040579504,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.90723925345805,
#           'lng': -56.210714040579504}],
#         'distance': 1773,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Pérez Castellano 1461 (25 de mayo)',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '52f2ab2ebcbc57f1066b8b31',
#          'name': 'Chocolate Shop',
#          'pluralName': 'Chocolate Shops',
#          'shortName': 'Chocolate Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/candystore_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4f43ba5fe4b03c8ff6d2112b-97'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '58a235e44f218a1fc68bb9fe',
#        'name': 'The Lab Coffee Roasters',
#        'location': {'address': 'Sarandí 285',
#         'lat': -34.908492535417686,
#         'lng': -56.135975318970274,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.908492535417686,
#           'lng': -56.135975318970274}],
#         'distance': 5064,
#         'postalCode': '11000',
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Sarandí 285',
#          '11000 Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'shortName': 'Coffee Shop',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-58a235e44f218a1fc68bb9fe-98'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d8644bf5e70224b0d413309',
#        'name': 'Heladeria García',
#        'location': {'address': 'Millán 3229',
#         'lat': -34.8678255616449,
#         'lng': -56.19200488863183,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': -34.8678255616449,
#           'lng': -56.19200488863183}],
#         'distance': 4239,
#         'cc': 'UY',
#         'city': 'Montevideo',
#         'state': 'Montevideo',
#         'country': 'Uruguay',
#         'formattedAddress': ['Millán 3229',
#          'Montevideo Montevideo',
#          'Uruguay']},
#        'categories': [{'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'shortName': 'Ice Cream',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d8644bf5e70224b0d413309-99'}]}]}}

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
venues = results['response']['groups'][0]['items']
    
nearby_venues = json_normalize(venues) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories', 'venue.location.lat', 'venue.location.lng']
nearby_venues =nearby_venues.loc[:, filtered_columns]

# filter the category for each row
nearby_venues['venue.categories'] = nearby_venues.apply(get_category_type, axis=1)

# clean columns
nearby_venues.columns = [col.split(".")[-1] for col in nearby_venues.columns]

nearby_venues.columns = ['Name','Category','Latitude','Longitude']

nearby_venues.head()
# Out:
# C:\Users\jpuma\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                            Name                Category  \
# 0  Auditorio Nacional del Sodre Dra. Adela Reta            Concert Hall
# 1                                Ashot Shawarma        Kebab Restaurant
# 2                        Smart Hotel Montevideo                   Hotel
# 3                                    La Ibérica  Furniture / Home Store
# 4                             Candy Bar Palermo                     Bar
#
#     Latitude  Longitude
# 0 -34.904490 -56.198395
# 1 -34.907314 -56.190219
# 2 -34.908406 -56.197819
# 3 -34.905319 -56.201069
# 4 -34.910187 -56.185020

# %%
print('{} venues were returned by Foursquare.'.format(nearby_venues.shape[0]))
# Out:
# 100 venues were returned by Foursquare.

# %% [markdown]
# #### Cluster the venues. After inspection it is confirmed these clusters are good proxies for the neighborhoods in Montevideo (no geospatial data available found).

# %%
# set number of clusters
kclusters = 7

mvd_clustering = nearby_venues.drop(['Name','Category'], 1)

# run k-means clustering
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(mvd_clustering)

# check cluster labels generated for each row in the dataframe
kmeans.labels_[0:10]
# Out:
# array([3, 1, 3, 3, 1, 3, 3, 3, 1, 3])

# %%
# add clustering labels
nearby_venues.insert(0, 'Cluster Labels', kmeans.labels_)

# %%
nearby_venues.head()
# Out:
#    Cluster Labels                                          Name  \
# 0               3  Auditorio Nacional del Sodre Dra. Adela Reta
# 1               1                                Ashot Shawarma
# 2               3                        Smart Hotel Montevideo
# 3               3                                    La Ibérica
# 4               1                             Candy Bar Palermo
#
#                  Category   Latitude  Longitude
# 0            Concert Hall -34.904490 -56.198395
# 1        Kebab Restaurant -34.907314 -56.190219
# 2                   Hotel -34.908406 -56.197819
# 3  Furniture / Home Store -34.905319 -56.201069
# 4                     Bar -34.910187 -56.185020

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=13)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add Venue markers to the map
markers_colors = []
for lat, lon, name, cluster in zip(nearby_venues['Latitude'], nearby_venues['Longitude'], nearby_venues['Name'], nearby_venues['Cluster Labels']):
    label = folium.Popup(str(name) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Load information about Police Stations in Uruguay. The data was previously obtained from Uruguayan government site, downloaded to a .txt file.

# %%
df_police = pd.read_csv('comisarias.txt') #import Uruguay Police information

#remove parenthesis from location fields
df_police['LON'] = df_police['LON'].replace('\(','', regex=True)
df_police['LON'] = df_police['LON'].replace('\)','', regex=True)
df_police['LAT'] = df_police['LAT'].replace('\(','', regex=True)
df_police['LAT'] = df_police['LAT'].replace('\)','', regex=True)
df_police.head()
# Out:
#    NRO  RECURSO                    NOMBRE  DESCRIPCION            DIRECCION  \
# 0    1  Policía  Seccional 12 Cerro Largo          NaN  undefined undefined
# 1    2  Policía  Seccional 14 Cerro Largo          NaN  undefined undefined
# 2    3  Policía       Seccional 4 C.Largo          NaN  undefined undefined
# 3    4  Policía       Seccional 5 C.Largo          NaN  undefined undefined
# 4    5  Policía        Sub. Cria. C.Largo          NaN  undefined undefined
#
#    TELEFONO  CORREO  OBSERVACION                  LON                  LAT
# 0       NaN     NaN          NaN  -53.981129636258004  -32.342184518895564
# 1       NaN     NaN          NaN   -54.17770399994951   -32.34168200088537
# 2       NaN     NaN          NaN   -53.74546099990412   -32.10700600085456
# 3       NaN     NaN          NaN   -54.12363099994595  -31.960464000876435
# 4       NaN     NaN          NaN   -54.16259799994918  -31.872311000876657

# %% [markdown]
# ### Drop unnecesary fields and only consider Police Stations in Uruguay's capital: Montevideo

# %%
df_police_mvd = df_police[df_police['NOMBRE'].str.contains('Montevideo')] #select Police only in Montevideo
df_police_mvd = df_police_mvd.reset_index(drop=True) #reset index
df_police_mvd = df_police_mvd.drop(['RECURSO','NRO','DESCRIPCION','DIRECCION','TELEFONO','CORREO','OBSERVACION'], axis=1) #drop empty fields
df_police_mvd.columns = ['Name','Longitude','Latitude']

df_police_mvd['Longitude'] = df_police_mvd['Longitude'].astype(float)
df_police_mvd['Latitude'] = df_police_mvd['Latitude'].astype(float)
df_police_mvd.dtypes

df_police_mvd = df_police_mvd.drop(axis=0, index=18) #drop "Jefatura"
df_police_mvd = df_police_mvd.reset_index(drop=True)

df_police_mvd.head()
# Out:
#                                  Name  Longitude   Latitude
# 0  Comisaria Seccional 18 Montevideo. -56.085709 -34.800053
# 1  Comisaria Seccional 16 Montevideo. -56.144316 -34.850426
# 2   Comisaria Seccional 25 Montevideo -56.116258 -34.837025
# 3   Comisaria Seccional 17 Montevideo -56.164098 -34.795132
# 4   Comisaria Seccional 10 Montevideo -56.150280 -34.907021

# %%
# add Seccional field
import re
df_police_mvd['Seccional'] = df_police_mvd['Name'].str.findall(r'\d+')

seccional = df_police_mvd['Seccional']

for key,value in enumerate(seccional):
    n_seccional = value[0]    
    #print(key, n_seccional)
    df_police_mvd['Seccional'][key] = n_seccional
# Out:
# C:\Users\jpuma\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
df_police_mvd['Seccional']=df_police_mvd['Seccional'].astype(int)
df_police_mvd.head()
# Out:
#                                  Name  Longitude   Latitude  Seccional
# 0  Comisaria Seccional 18 Montevideo. -56.085709 -34.800053         18
# 1  Comisaria Seccional 16 Montevideo. -56.144316 -34.850426         16
# 2   Comisaria Seccional 25 Montevideo -56.116258 -34.837025         25
# 3   Comisaria Seccional 17 Montevideo -56.164098 -34.795132         17
# 4   Comisaria Seccional 10 Montevideo -56.150280 -34.907021         10

# %% [markdown]
# ### Load the information of Crimes per Police Station.The data was previously obtained from Uruguayan government site, downloaded to an excel file.

# %%
# import number of crimes reported per police station
df_denuncias = pd.read_excel('Denuncias.xlsx')
df_denuncias.head()
# Out:
#   Seccional  Denuncias (Hurto y Rapina)
# 0         9                         350
# 1         8                         639
# 2         7                         395
# 3         6                         158
# 4         5                         297

# %%
df_denuncias = df_denuncias.drop(df_denuncias.index[[25,26]]) #drop PREFECTURA
df_denuncias = df_denuncias.drop(axis=0, index=2) #drop empty row

# %%
df_denuncias['Seccional'] = df_denuncias['Seccional'].astype(int)

# %%
df_denuncias.head()
# Out:
#    Seccional  Denuncias (Hurto y Rapina)
# 0          9                         350
# 1          8                         639
# 3          6                         158
# 4          5                         297
# 5          4                         250

# %% [markdown]
# ### Merge Police Station location data with Number of Crimes

# %%
df_police_merged = pd.merge(df_police_mvd,df_denuncias, on='Seccional')

# %%
df_police_merged.columns = ['Name','Longitude','Latitude','Seccional','N_Crimes']
df_police_merged.head()
# Out:
#                                  Name  Longitude   Latitude  Seccional  \
# 0  Comisaria Seccional 18 Montevideo. -56.085709 -34.800053         18
# 1  Comisaria Seccional 16 Montevideo. -56.144316 -34.850426         16
# 2   Comisaria Seccional 25 Montevideo -56.116258 -34.837025         25
# 3   Comisaria Seccional 17 Montevideo -56.164098 -34.795132         17
# 4   Comisaria Seccional 10 Montevideo -56.150280 -34.907021         10
#
#    N_Crimes
# 0       789
# 1       928
# 2       544
# 3      1213
# 4       260

# %% [markdown]
# ## Generate Map with Police Station location, bubble size indicating Number of Crimes, and venue locations.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=12)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add Venue markers to the map
markers_colors = []
for lat, lon, name, cluster in zip(nearby_venues['Latitude'], nearby_venues['Longitude'], nearby_venues['Name'], nearby_venues['Cluster Labels']):
    label = folium.Popup(str(name) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color='blue',#rainbow[cluster-1],
        fill=True,
        fill_color='blue',#rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
    
for Name, Latitude, Longitude, Crimes in zip(df_police_merged['Name'], df_police_merged['Latitude'], df_police_merged['Longitude'],df_police_merged['N_Crimes']):
    label = '{}, {}'.format(Number, Name)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [Latitude, Longitude],
        radius=(Crimes/100)*5,
        popup=label,
        color='crimson',
        fill=True,
        fill_color='crimson',
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Results
# ### The map clearly shows a higher number of crimes in the outskirts of the city, were there is practically no presence of Foursquare venues. As mentioned previously, the Foursquare app is used mainly by tourists and high-income Uruguayans, so the location of the venues available in Foursquare can be used as a proxy for more policed and better-off areas.
#
#
# # Conclusion
# ### The main conclusion of the analysis is that crime rate and police presence/economic-status appear to be inversely related, with higher crime rate in areas with less police presence and/or lower economic-status.
